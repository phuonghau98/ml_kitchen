# %%
from pandas import read_csv
from sklearn import linear_model
from sklearn.metrics import mean_squared_error

# %%
features = ['age', 'sex', 'bmi', 'blood_pressure', 'serum1', 'serum2', 'serum3', 'serum4', 'serum5', 'serum6']
data = read_csv('/home/phuong/kitchen/ml/regression/diabetes/diabetes-regression/diabetes-data.csv', header=None, names=features + ['result'])

# %%
data
# Out:
#      age  sex   bmi  blood_pressure  serum1  serum2  serum3  serum4  serum5  \
# 0     59    2  32.1          101.00     157    93.2    38.0    4.00  4.8598
# 1     48    1  21.6           87.00     183   103.2    70.0    3.00  3.8918
# 2     72    2  30.5           93.00     156    93.6    41.0    4.00  4.6728
# 3     24    1  25.3           84.00     198   131.4    40.0    5.00  4.8903
# 4     50    1  23.0          101.00     192   125.4    52.0    4.00  4.2905
# ..   ...  ...   ...             ...     ...     ...     ...     ...     ...
# 437   60    2  28.2          112.00     185   113.8    42.0    4.00  4.9836
# 438   47    2  24.9           75.00     225   166.0    42.0    5.00  4.4427
# 439   60    2  24.9           99.67     162   106.6    43.0    3.77  4.1271
# 440   36    1  30.0           95.00     201   125.2    42.0    4.79  5.1299
# 441   36    1  19.6           71.00     250   133.2    97.0    3.00  4.5951
#
#      serum6  result
# 0        87     151
# ...

# %%
def one_feature_regression(x, y, f):
    regr = linear_model.LinearRegression()
    x1 = data['age']
    regr.fit(x1, y)
    y
# Out:
# 0      59
# 1      48
# 2      72
# 3      24
# 4      50
#        ..
# 437    60
# 438    47
# 439    60
# 440    36
# 441    36
# Name: age, Length: 442, dtype: int64
